# %% [markdown]
# # Install if Missing

# %%
# !pip install opendatasets 
# !pip install pandas
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opendatasets in c:\users\the just\appdata\roaming\python\python39\site-packages (0.1.22)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: kaggle in c:\users\the just\appdata\roaming\python\python39\site-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->opendatasets) (0.4.6)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2023.7.22)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (6.0.0)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: python-slugify in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (8.0.0)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.26.14)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.28.2)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (3.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\the just\appdata\roaming\python\python39\site-packages (1.9.2)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\the just\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (20.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (5.10.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.13.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import opendatasets as od
import pandas as pd
import numpy as np
import os

# %%
od.download(
    "https://www.kaggle.com/datasets/andrewmvd/ocular-disease-recognition-odir5k")
# Out:
# Skipping, found downloaded files in "./ocular-disease-recognition-odir5k" (use force=True to force download)

# %% [markdown]
# Read Downloaded Images and Display them

# %%
path_to_images = "./ocular-disease-recognition-odir5k/"

training_path = "ODIR-5k/ODIR-5k/Training Images"
test_path = "ODIR-5k/ODIR-5k/Testing Images"
preprocessed_images = "preprocessed_images"

print("Training Images Length: ", len(os.listdir(os.path.join(path_to_images, training_path))))
print("Testing Images Length: ", len(os.listdir(os.path.join(path_to_images, test_path))))
print("Preprocessed Images Length: ", len(os.listdir(os.path.join(path_to_images, preprocessed_images))))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 test_path = "ODIR-5k/ODIR-5k/Testing Images"
#       5 preprocessed_images = "preprocessed_images"
# ----> 7 print("Training Images Length: ", len(os.listdir(os.path.join(path_to_images, training_path))))
#       8 print("Testing Images Length: ", len(os.listdir(os.path.join(path_to_images, test_path))))
#       9 print("Preprocessed Images Length: ", len(os.listdir(os.path.join(path_to_images, preprocessed_images))))
#
# FileNotFoundError: [Errno 2] No such file or directory: './ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images'

# %% [markdown]
# > This tells me there might be repeated files so i'll take a look at the full data

# %%
original_dataframe = pd.read_excel("./ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/data.xlsx")

# %%
original_dataframe.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
original_dataframe.columns
original_dataframe.rename(columns = {'Left-Diagnostic Keywords':'LD'}, inplace = True)
original_dataframe.rename(columns = {'Right-Diagnostic Keywords':'RD'}, inplace = True)

# %%
duplicateRows = original_dataframe[original_dataframe.duplicated()]

# %%
len(original_dataframe)
# Out:
# 3500

# %% [markdown]
# > - No duplicate Rows
# > - From the length we can tell we should be expecting 7000 images (i.e. 2 eyes per individual)

# %%
list_of_training_images = os.listdir(os.path.join(path_to_images, training_path))
list_of_testing_images = os.listdir(os.path.join(path_to_images, test_path))

# %%
print(len(list_of_testing_images),len(list_of_training_images))
# Out:
# 1000 7000

# %%
training_images = [x for x in list_of_training_images if x not in list_of_testing_images]

# %%
'0_left.jpg' in list_of_testing_images
# Out:
# False

# %% [markdown]
# - Evidently there are 8000 images in total.
# - 7000 for training and 1000 for testing that should result in 8000 people in total, but the csv file only has 3500 entries which indicates the test set does not have labels

# %% [markdown]
# # Word Clouds

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# %matplotlib inline

# %%
left_text = " ".join(review + ',' for review in original_dataframe.LD)

# %%
wordcloud = WordCloud(background_color="white").generate(left_text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# This visual indicates that the there is an error in the string being visualised. Further exploration is necessary.

# %%
list_left_diagnosis = left_text.split(',') #take the original left_text and split on commas.
#this should identify all the entries per rows.
set_left_diagnosis = set(list_left_diagnosis) #find the unique items

# %%
len(set_left_diagnosis)
# Out:
# 229

# %%
set_left_diagnosis
# Out:
# {'',
#  ' anterior segment image',
#  ' asteroid hyalosis',
#  ' atrophy',
#  ' branch retinal artery occlusion',
#  ' branch retinal vein occlusion',
#  ' branch retinal vein occlusion，lens dust',
#  ' cataract',
#  ' cataract，lens dust',
#  ' cataract，mild nonproliferative retinopathy',
#  ' cataract，moderate non proliferative retinopathy',
#  ' cataract，myelinated nerve fibers，moderate non proliferative retinopathy',
#  ' cataract，suspected glaucoma',
#  ' central retinal vein occlusion',
#  ' central retinal vein occlusion，optic disc edema',
#  ' chorioretinal atrophy',
#  ' chorioretinal atrophy with pigmentation proliferation',
#  ' chorioretinal atrophy with pigmentation proliferation，epiretinal membrane',
#  ' chorioretinal atrophy with pigmentation proliferation，lens dust',
#  ' chorioretinal atrophy，chorioretinal atrophy',
#  ' depigmentation of the retinal pigment epithelium',
#  ' diabetic retinopathy',
#  ' diabetic retinopathy，dry age-related macular degeneration',
#  ' diabetic retinopathy，post laser photocoagulation',
#  ' diabetic retinopathy，wet age-related macular degeneration',
#  ' diabetic retinopathy，wet age-related macular degeneration，macular epiretinal membrane',
#  ' drusen',
#  ' drusen，branch retinal vein occlusion',
#  ' drusen，cataract，lens dust',
#  ' drusen，lens dust',
#  ' drusen，mild nonproliferative retinopathy',
#  ' dry age-related macular degeneration',
#  ' dry age-related macular degeneration，choroidal nevus',
#  ' dry age-related macular degeneration，diabetic retinopathy',
#  ' dry age-related macular degeneration，glaucoma',
#  ' dry age-related macular degeneration，hypertensive retinopathy',
#  ' dry age-related macular degeneration，myopia retinopathy',
#  ' epiretinal membrane',
#  ' epiretinal membrane over the macula',
#  ' epiretinal membrane over the macula，white vessel',
#  ' epiretinal membrane，chorioretinal atrophy',
#  ' epiretinal membrane，drusen',
#  ' epiretinal membrane，epiretinal membrane，lens dust',
#  ' epiretinal membrane，laser spot，severe proliferative diabetic retinopathy',
#  ' epiretinal membrane，lens dust',
#  ' epiretinal membrane，mild nonproliferative retinopathy',
#  ' epiretinal membrane，moderate non proliferative retinopathy',
#  ' epiretinal membrane，moderate non proliferative retinopathy，laser spot',
#  ' epiretinal membrane，myelinated nerve fibers',
#  ' epiretinal membrane，normal fundus，lens dust',
#  ' fundus laser photocoagulation spots',
#  ' glaucoma',
#  ' glaucoma，central retinal vein occlusion',
#  ' glaucoma，diabetic retinopathy',
#  ' glaucoma，diffuse retinal atrophy',
#  ' glaucoma，hypertensive retinopathy',
#  ' glaucoma，intraretinal hemorrhage',
#  ' glaucoma，lens dust',
#  ' glaucoma，macular epiretinal membrane',
#  ' glaucoma，mild nonproliferative retinopathy，macular pigmentation disorder',
#  ' glaucoma，moderate non proliferative retinopathy',
#  ' glaucoma，myopia retinopathy',
#  ' glaucoma，optic nerve atrophy',
#  ' glaucoma，wet age-related macular degeneration',
#  ' hypertensive retinopathy',
#  ' hypertensive retinopathy，age-related macular degeneration',
#  ' hypertensive retinopathy，cataract',
#  ' hypertensive retinopathy，diabetic retinopathy',
#  ' hypertensive retinopathy，mild nonproliferative retinopathy',
#  ' hypertensive retinopathy，moderate non proliferative retinopathy',
#  ' hypertensive retinopathy，optic nerve atrophy',
#  ' hypertensive retinopathy，suspected diabetic retinopathy',
#  ' hypertensive retinopathy，suspected glaucoma',
#  ' idiopathic choroidal neovascularization',
#  ' image offset',
#  ' laser spot',
#  ' laser spot，branch retinal vein occlusion',
#  ' laser spot，cataract',
#  ' laser spot，chorioretinal atrophy，glaucoma',
#  ' laser spot，macular epiretinal membrane',
#  ' laser spot，mild nonproliferative retinopathy',
#  ' laser spot，moderate non proliferative retinopathy',
#  ' laser spot，moderate non proliferative retinopathy，macular epiretinal membrane',
#  ' laser spot，proliferative diabetic retinopathy，white vessel',
#  ' laser spot，severe nonproliferative retinopathy，white vessel',
#  ' laser spot，severe proliferative diabetic retinopathy',
#  ' laser spot，vitreous degeneration，mild nonproliferative retinopathy',
#  ' laser spot，white vessel',
#  ' laser spot，white vessel，moderate non proliferative retinopathy',
#  ' lens dust，cataract',
#  ' lens dust，drusen',
#  ' lens dust，epiretinal membrane',
#  ' lens dust，epiretinal membrane，glaucoma，moderate non proliferative retinopathy',
#  ' lens dust，glaucoma',
#  ' lens dust，lens dust',
#  ' lens dust，lens dust，lens dust',
#  ' lens dust，macular epiretinal membrane',
#  ' lens dust，mild nonproliferative retinopathy',
#  ' lens dust，mild nonproliferative retinopathy，myelinated nerve fibers',
#  ' lens dust，moderate non proliferative retinopathy',
#  ' lens dust，myelinated nerve fibers',
#  ' lens dust，normal fundus',
#  ' lens dust，pathological myopia',
#  ' lens dust，rhegmatogenous retinal detachment',
#  ' lens dust，spotted membranous change',
#  ' lens dust，vitreous degeneration',
#  ' low image quality',
#  ' macular coloboma',
#  ' macular epiretinal membrane',
#  ' macular epiretinal membrane，glaucoma',
#  ' macular epiretinal membrane，laser spot',
#  ' macular epiretinal membrane，lens dust',
#  ' macular epiretinal membrane，mild nonproliferative retinopathy',
#  ' macular epiretinal membrane，moderate non proliferative retinopathy',
#  ' macular epiretinal membrane，moderate non proliferative retinopathy，laser spot',
#  ' macular epiretinal membrane，severe nonproliferative retinopathy',
#  ' macular epiretinal membrane，vessel tortuosity',
#  ' macular hole',
#  ' maculopathy',
#  ' maculopathy，glaucoma',
#  ' maculopathy，macular epiretinal membrane',
#  ' mild nonproliferative retinopathy',
#  ' mild nonproliferative retinopathy，drusen',
#  ' mild nonproliferative retinopathy，dry age-related macular degeneration',
#  ' mild nonproliferative retinopathy，epiretinal membrane',
#  ' mild nonproliferative retinopathy，epiretinal membrane over the macula',
#  ' mild nonproliferative retinopathy，hypertensive retinopathy',
#  ' mild nonproliferative retinopathy，lens dust，drusen',
#  ' mild nonproliferative retinopathy，macular epiretinal membrane',
#  ' mild nonproliferative retinopathy，mild nonproliferative retinopathy',
#  ' mild nonproliferative retinopathy，myelinated nerve fibers',
#  ' mild nonproliferative retinopathy，retinal pigmentation',
#  ' mild nonproliferative retinopathy，vitreous degeneration',
#  ' moderate non proliferative retinopathy',
#  ' moderate non proliferative retinopathy，atrophic change',
#  ' moderate non proliferative retinopathy，branch retinal vein occlusion',
#  ' moderate non proliferative retinopathy，cataract',
#  ' moderate non proliferative retinopathy，chorioretinal atrophy',
#  ' moderate non proliferative retinopathy，drusen',
#  ' moderate non proliferative retinopathy，epiretinal membrane',
#  ' moderate non proliferative retinopathy，glaucoma',
#  ' moderate non proliferative retinopathy，hypertensive retinopathy',
#  ' moderate non proliferative retinopathy，laser spot',
#  ' moderate non proliferative retinopathy，lens dust',
#  ' moderate non proliferative retinopathy，lens dust，drusen',
#  ' moderate non proliferative retinopathy，macular epiretinal membrane',
#  ' moderate non proliferative retinopathy，myelinated nerve fibers',
#  ' moderate non proliferative retinopathy，myelinated nerve fibers，laser spot',
#  ' moderate non proliferative retinopathy，optic disc edema',
#  ' moderate non proliferative retinopathy，pathological myopia',
#  ' moderate non proliferative retinopathy，refractive media opacity',
#  ' moderate non proliferative retinopathy，retina fold',
#  ' moderate non proliferative retinopathy，suspected glaucoma',
#  ' moderate non proliferative retinopathy，vitreous degeneration',
#  ' moderate non proliferative retinopathy，white vessel',
#  ' myelinated nerve fibers',
#  ' myelinated nerve fibers，moderate non proliferative retinopathy',
#  ' myelinated nerve fibers，suspected glaucoma',
#  ' myopic maculopathy',
#  ' myopic retinopathy',
#  ' no fundus image',
#  ' normal fundus',
#  ' normal fundus，lens dust',
#  ' normal fundus，normal fundus',
#  ' old branch retinal vein occlusion',
#  ' old central retinal vein occlusion',
#  ' old chorioretinopathy',
#  ' old choroiditis，macular epiretinal membrane',
#  ' optic disc edema',
#  ' optic disc edema，central retinal vein occlusion',
#  ' optic disk epiretinal membrane',
#  ' optic disk photographically invisible',
#  ' optic nerve atrophy',
#  ' optic nerve atrophy，dry age-related macular degeneration',
#  ' pathological myopia',
#  ' peripapillary atrophy',
#  ' pigment epithelium proliferation',
#  ' post laser photocoagulation，diabetic retinopathy',
#  ' post laser photocoagulation，glaucoma',
#  ' post retinal laser surgery，diabetic retinopathy',
#  ' post retinal laser surgery，moderate non proliferative retinopathy',
#  ' post retinal laser surgery，proliferative diabetic retinopathy',
#  ' post retinal laser surgery，severe nonproliferative retinopathy',
#  ' proliferative diabetic retinopathy',
#  ' proliferative diabetic retinopathy，hypertensive retinopathy',
#  ' punctate inner choroidopathy，myopia retinopathy',
#  ' refractive media opacity',
#  ' refractive media opacity，pathological myopia',
#  ' retinal pigment epithelium atrophy，diabetic retinopathy',
#  ' retinal pigmentation',
#  ' retinal pigmentation，epiretinal membrane',
#  ' retinitis pigmentosa',
#  ' retinochoroidal coloboma',
#  ' rhegmatogenous retinal detachment',
#  ' severe nonproliferative retinopathy',
#  ' severe nonproliferative retinopathy，hypertensive retinopathy',
#  ' severe nonproliferative retinopathy，white vessel',
#  ' severe proliferative diabetic retinopathy',
#  ' silicone oil eye',
#  ' spotted membranous change',
#  ' spotted membranous change，spotted membranous change',
#  ' suspected glaucoma',
#  ' suspected glaucoma，drusen',
#  ' suspected glaucoma，mild nonproliferative retinopathy',
#  ' suspected glaucoma，moderate non proliferative retinopathy',
#  ' suspected glaucoma，refractive media opacity',
#  ' suspected glaucoma，suspicious diabetic retinopathy',
#  ' suspected moderate non proliferative retinopathy，pathological myopia',
#  ' suspected retinal vascular sheathing',
#  ' tessellated fundus',
#  ' tessellated fundus，chorioretinal atrophy',
#  ' tessellated fundus，peripapillary atrophy',
#  ' tessellated fundus，suspected glaucoma',
#  ' vitreous degeneration',
#  ' vitreous degeneration，lens dust',
#  ' vitreous degeneration，mild nonproliferative retinopathy',
#  ' vitreous degeneration，vitreous degeneration',
#  ' wedge white line change',
#  ' wet age-related macular degeneration',
#  ' wet age-related macular degeneration，diffuse chorioretinal atrophy',
#  ' wet age-related macular degeneration，myopia retinopathy',
#  ' white vessel，arteriosclerosis',
#  ' white vessel，laser spot',
#  ' white vessel，moderate non proliferative retinopathy',
#  ' white vessel，severe nonproliferative retinopathy',
#  ' white vessel，suspected glaucoma',
#  'cataract',
#  'diabetic retinopathy',
#  'maculopathy'}

# %% [markdown]
# From the set above, it can be seen that there are terms in the list that are still aplit with the character '，'. This tells us that the content in the column need to have that character replaced with a comma.
# Additionally we also saw that there were items in the diagnosis columns that had a space before the item. so we need to account for this as well.

# %%
left_text = "".join(i + ',' for review in original_dataframe.LD for i in review.split('，')) 
right_text = "".join(i + ',' for review in original_dataframe.RD for i in review.split('，'))
left_text += right_text
#attempting to split on the character discovered earlier.

# %%
#display word cloud again #use frequency of words instead of the text
wordcloud = WordCloud(background_color="white").generate(left_text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def remove_special_comma(diagnosis):
    diagnosis = diagnosis.replace('，', ',')
    return diagnosis

# %%
original_dataframe['LD'] = original_dataframe['LD'].map(remove_special_comma) 
original_dataframe['RD'] = original_dataframe['RD'].map(remove_special_comma)

# %%
original_dataframe.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                                                   LD  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot,moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                                        RD  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
original_dataframe.head(5)
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                                                   LD  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot,moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                                        RD  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %% [markdown]
# There has to be a way to figure out what terms lead to what diagnosis.
# Presently the data has two images per row (person) and we can either make it a row per eye and adjust the labels accordingly or cocantenate two eyes when passing the image to the model.
#
# The Labels are as follow:
# - Normal (N),
# - Diabetes (D),
# - Glaucoma (G),
# - Cataract (C),
# - Age related Macular Degeneration (A),
# - Hypertension (H),
# - Pathological Myopia (M),
# - Other diseases/abnormalities (O)
#
# We can select the columns that have a positive presence (1) for each of these columns and note the terms that most correlate with them.

# %%
normal_fundus = original_dataframe[original_dataframe['N'] == 1]
diabetes = original_dataframe[original_dataframe['D'] == 1]
glaucoma = original_dataframe[original_dataframe['G'] == 1]
cataract = original_dataframe[original_dataframe['C'] == 1]
armd = original_dataframe[original_dataframe['A'] == 1]
hypertension = original_dataframe[original_dataframe['H'] == 1]
myopia = original_dataframe[original_dataframe['M'] == 1]
others = original_dataframe[original_dataframe['O'] == 1]

# %% [markdown]
# For each of the tables above, we want to find out the diagnosis terms that most generate those results. We can accomplish this by taking a set of unique elements from the LD and RD columns. We'll then eliminate any overlap with any of the other sets for other labels.

# %%
def text_to_set(text):
    """
        Takes a text and returns a set of unique words in the text.
        Args:
            text (String): a text splittable with commas
        returns:
            set
    """
    text_list = text.split(',')
    return set(text_list)

# %%
def extract_text_from_diagnosis_columns(dataframe):
    text_left = "".join(i + ',' for review in dataframe.LD for i in review.split(',')) 
    text_right = "".join(i + ',' for review in dataframe.RD for i in review.split(',')) 
    text = text_left + text_right
    return text

# %%
original_diagnosis = extract_text_from_diagnosis_columns(original_dataframe)

# %%
original_diagnosis_set = text_to_set(original_diagnosis)

# %%
len(original_diagnosis_set)
# Out:
# 103

# %%
original_diagnosis_set
# Out:
# {'',
#  'abnormal pigment ',
#  'age-related macular degeneration',
#  'anterior segment image',
#  'arteriosclerosis',
#  'asteroid hyalosis',
#  'atrophic change',
#  'atrophy',
#  'branch retinal artery occlusion',
#  'branch retinal vein occlusion',
#  'cataract',
#  'central retinal artery occlusion',
#  'central retinal vein occlusion',
#  'central serous chorioretinopathy',
#  'chorioretinal atrophy',
#  'chorioretinal atrophy with pigmentation proliferation',
#  'choroidal nevus',
#  'congenital choroidal coloboma',
#  'depigmentation of the retinal pigment epithelium',
#  'diabetic retinopathy',
#  'diffuse chorioretinal atrophy',
#  'diffuse retinal atrophy',
#  'drusen',
#  'dry age-related macular degeneration',
#  'epiretinal membrane',
#  'epiretinal membrane over the macula',
#  'fundus laser photocoagulation spots',
#  'glaucoma',
#  'glial remnants anterior to the optic disc',
#  'hypertensive retinopathy',
#  'idiopathic choroidal neovascularization',
#  'image offset',
#  'intraretinal hemorrhage',
#  'intraretinal microvascular abnormality',
#  'laser spot',
#  'lens dust',
#  'low image quality',
#  'macular coloboma',
#  'macular epiretinal membrane',
#  'macular hole',
#  'macular pigmentation disorder',
#  'maculopathy',
#  'mild nonproliferative retinopathy',
#  'moderate non proliferative retinopathy',
#  'morning glory syndrome',
#  'myelinated nerve fibers',
#  'myopia retinopathy',
#  'myopic maculopathy',
#  'myopic retinopathy',
#  'no fundus image',
#  'normal fundus',
#  'old branch retinal vein occlusion',
#  'old central retinal vein occlusion',
#  'old chorioretinopathy',
#  'old choroiditis',
#  'optic disc edema',
#  'optic discitis',
#  'optic disk epiretinal membrane',
#  'optic disk photographically invisible',
#  'optic nerve atrophy',
#  'oval yellow-white atrophy',
#  'pathological myopia',
#  'peripapillary atrophy',
#  'pigment epithelium proliferation',
#  'pigmentation disorder',
#  'post laser photocoagulation',
#  'post retinal laser surgery',
#  'proliferative diabetic retinopathy',
#  'punctate inner choroidopathy',
#  'refractive media opacity',
#  'retina fold',
#  'retinal artery macroaneurysm',
#  'retinal detachment',
#  'retinal pigment epithelial hypertrophy',
#  'retinal pigment epithelium atrophy',
#  'retinal pigmentation',
#  'retinal vascular sheathing',
#  'retinitis pigmentosa',
#  'retinochoroidal coloboma',
#  'rhegmatogenous retinal detachment',
#  'severe nonproliferative retinopathy',
#  'severe proliferative diabetic retinopathy',
#  'silicone oil eye',
#  'spotted membranous change',
#  'suspected abnormal color of  optic disc',
#  'suspected cataract',
#  'suspected diabetic retinopathy',
#  'suspected glaucoma',
#  'suspected macular epimacular membrane',
#  'suspected microvascular anomalies',
#  'suspected moderate non proliferative retinopathy',
#  'suspected retinal vascular sheathing',
#  'suspected retinitis pigmentosa',
#  'suspicious diabetic retinopathy',
#  'tessellated fundus',
#  'vascular loops',
#  'vessel tortuosity',
#  'vitreous degeneration',
#  'vitreous opacity',
#  'wedge white line change',
#  'wedge-shaped change',
#  'wet age-related macular degeneration',
#  'white vessel'}

# %% [markdown]
# Having found out the set of all diagnostical terms across the LD and RD columns, the next step is to isolate the terms that uniquely identify a particular label.

# %%
pd.set_option('display.max_rows', None) #change the number of max rows available for display

# %%
others_left = "".join(i + ',' for review in others.LD for i in review.split(',')) 
others_right = "".join(i + ',' for review in others.RD for i in review.split(',')) 
others_text = others_left + others_right

# %%
pure_normal_fundus = normal_fundus[(normal_fundus['C'] == 0) & (normal_fundus['N'] == 1) & (normal_fundus['A'] == 0) & (normal_fundus['G'] == 0)
                          & (normal_fundus['H'] == 0) & (normal_fundus['M'] == 0) & (normal_fundus['D'] == 0) & (normal_fundus['O'] == 0)]
pure_normal_fundus_text = extract_text_from_diagnosis_columns(pure_normal_fundus)
pure_normal_fundus_set = text_to_set(pure_normal_fundus_text)

# %%
pure_cataract = cataract[(cataract['C'] == 1) & (cataract['N'] == 0) & (cataract['A'] == 0) & (cataract['G'] == 0)
                          & (cataract['H'] == 0) & (cataract['M'] == 0) & (cataract['D'] == 0) & (cataract['O'] == 0)]
pure_cataract_text = extract_text_from_diagnosis_columns(pure_cataract)
pure_cataract_set = text_to_set(pure_cataract_text)
pure_cataract_set -= pure_normal_fundus_set

# %%
pure_diabetes = diabetes[(diabetes['C'] == 0) & (diabetes['N'] == 0) & (diabetes['A'] == 0) & (diabetes['G'] == 0)
                          & (diabetes['H'] == 0) & (diabetes['M'] == 0) & (diabetes['D'] == 1) & (diabetes['O'] == 0)]
pure_diabetes_text = extract_text_from_diagnosis_columns(pure_diabetes)
pure_diabetes_set = text_to_set(pure_diabetes_text)
pure_diabetes_set -= pure_normal_fundus_set

# %%
pure_armd = armd[(armd['C'] == 0) & (armd['N'] == 0) & (armd['A'] == 1) & (armd['G'] == 0)
                          & (armd['H'] == 0) & (armd['M'] == 0) & (armd['D'] == 0) & (armd['O'] == 0)]
pure_armd_text = extract_text_from_diagnosis_columns(pure_armd)
pure_armd_set = text_to_set(pure_armd_text)
pure_armd_set -= pure_normal_fundus_set

# %%
pure_hypertension = hypertension[(hypertension['C'] == 0) & (hypertension['N'] == 0) & (hypertension['A'] == 0) & (hypertension['G'] == 0)
                          & (hypertension['H'] == 1) & (hypertension['M'] == 0) & (hypertension['D'] == 0) & (hypertension['O'] == 0)]
pure_hypertension_text = extract_text_from_diagnosis_columns(pure_hypertension)
pure_hypertension_set = text_to_set(pure_hypertension_text)
pure_hypertension_set -= pure_normal_fundus_set

# %%
pure_glaucoma = glaucoma[(glaucoma['C'] == 0) & (glaucoma['N'] == 0) & (glaucoma['A'] == 0) & (glaucoma['G'] == 1)
                          & (glaucoma['H'] == 0) & (glaucoma['M'] == 0) & (glaucoma['D'] == 0) & (glaucoma['O'] == 0)]
pure_glaucoma_text = extract_text_from_diagnosis_columns(pure_glaucoma)
pure_glaucoma_set = text_to_set(pure_glaucoma_text)
pure_glaucoma_set -= pure_normal_fundus_set

# %%
pure_myopia = myopia[(myopia['C'] == 0) & (myopia['N'] == 0) & (myopia['A'] == 0) & (myopia['G'] == 0)
                          & (myopia['H'] == 0) & (myopia['M'] == 1) & (myopia['D'] == 0) & (myopia['O'] == 0)]
pure_myopia_text = extract_text_from_diagnosis_columns(pure_myopia)
pure_myopia_set = text_to_set(pure_myopia_text)
pure_myopia_set -= pure_normal_fundus_set

# %%
pure_others = others[(others['C'] == 0) & (others['N'] == 0) & (others['A'] == 0) & (others['G'] == 0)
                          & (others['H'] == 0) & (others['M'] == 0) & (others['D'] == 0) & (others['O'] == 1)]
pure_others_text = extract_text_from_diagnosis_columns(pure_others)
pure_others_set = text_to_set(pure_others_text)
pure_others_set -= pure_normal_fundus_set

# %%
(pure_others_set & pure_diabetes_set & pure_cataract_set & pure_hypertension_set & pure_glaucoma_set & pure_myopia_set & pure_armd_set & pure_normal_fundus_set)
# Out:
# set()

# %% [markdown]
# There's no common element that leads to a pure diagnosis of a particular category. Hence we can hold that the presence of other terms will lead to a compound diagnosis.

# %%
total_pure_set = (pure_normal_fundus_set | pure_myopia_set | pure_glaucoma_set | pure_armd_set | pure_diabetes_set |
                         pure_hypertension_set | pure_cataract_set | pure_others_set)

# %%
total_pure_set
# Out:
# {'',
#  'abnormal pigment ',
#  'anterior segment image',
#  'arteriosclerosis',
#  'asteroid hyalosis',
#  'atrophic change',
#  'atrophy',
#  'branch retinal artery occlusion',
#  'branch retinal vein occlusion',
#  'cataract',
#  'central retinal artery occlusion',
#  'central retinal vein occlusion',
#  'chorioretinal atrophy',
#  'chorioretinal atrophy with pigmentation proliferation',
#  'congenital choroidal coloboma',
#  'depigmentation of the retinal pigment epithelium',
#  'diabetic retinopathy',
#  'drusen',
#  'dry age-related macular degeneration',
#  'epiretinal membrane',
#  'epiretinal membrane over the macula',
#  'glaucoma',
#  'hypertensive retinopathy',
#  'idiopathic choroidal neovascularization',
#  'laser spot',
#  'lens dust',
#  'low image quality',
#  'macular coloboma',
#  'macular epiretinal membrane',
#  'macular hole',
#  'maculopathy',
#  'mild nonproliferative retinopathy',
#  'moderate non proliferative retinopathy',
#  'morning glory syndrome',
#  'myelinated nerve fibers',
#  'myopic maculopathy',
#  'myopic retinopathy',
#  'no fundus image',
#  'normal fundus',
#  'old branch retinal vein occlusion',
#  'old chorioretinopathy',
#  'optic disc edema',
#  'optic discitis',
#  'optic disk photographically invisible',
#  'optic nerve atrophy',
#  'oval yellow-white atrophy',
#  'pathological myopia',
#  'pigment epithelium proliferation',
#  'pigmentation disorder',
#  'post laser photocoagulation',
#  'post retinal laser surgery',
#  'proliferative diabetic retinopathy',
#  'refractive media opacity',
#  'retina fold',
#  'retinal artery macroaneurysm',
#  'retinal pigmentation',
#  'retinal vascular sheathing',
#  'retinitis pigmentosa',
#  'retinochoroidal coloboma',
#  'rhegmatogenous retinal detachment',
#  'severe nonproliferative retinopathy',
#  'severe proliferative diabetic retinopathy',
#  'silicone oil eye',
#  'spotted membranous change',
#  'suspected abnormal color of  optic disc',
#  'suspected glaucoma',
#  'suspected retinal vascular sheathing',
#  'suspected retinitis pigmentosa',
#  'tessellated fundus',
#  'vessel tortuosity',
#  'vitreous degeneration',
#  'wedge white line change',
#  'wedge-shaped change',
#  'wet age-related macular degeneration',
#  'white vessel'}

# %%
len(total_pure_set)
# Out:
# 75

# %%
remaining_set = (original_diagnosis_set - (pure_normal_fundus_set | pure_myopia_set | pure_glaucoma_set | pure_armd_set | pure_diabetes_set |
                         pure_hypertension_set | pure_cataract_set | pure_others_set)) 
#trying to find the items not in any of the pure sets but in the total set of diagnosis terms

# %%
len(original_diagnosis_set) - len(total_pure_set)
# Out:
# 28

# %%
remaining_set
# Out:
# {'age-related macular degeneration',
#  'central serous chorioretinopathy',
#  'choroidal nevus',
#  'diffuse chorioretinal atrophy',
#  'diffuse retinal atrophy',
#  'fundus laser photocoagulation spots',
#  'glial remnants anterior to the optic disc',
#  'image offset',
#  'intraretinal hemorrhage',
#  'intraretinal microvascular abnormality',
#  'macular pigmentation disorder',
#  'myopia retinopathy',
#  'old central retinal vein occlusion',
#  'old choroiditis',
#  'optic disk epiretinal membrane',
#  'peripapillary atrophy',
#  'punctate inner choroidopathy',
#  'retinal detachment',
#  'retinal pigment epithelial hypertrophy',
#  'retinal pigment epithelium atrophy',
#  'suspected cataract',
#  'suspected diabetic retinopathy',
#  'suspected macular epimacular membrane',
#  'suspected microvascular anomalies',
#  'suspected moderate non proliferative retinopathy',
#  'suspicious diabetic retinopathy',
#  'vascular loops',
#  'vitreous opacity'}

# %%
len(remaining_set)
# Out:
# 28

# %% [markdown]
# Visually, some items can be placed in specific categories such as age-related macular degeneration, myopia retinopathy. These will be confirmed.

# %%
original_dataframe[original_dataframe['RD'].str.contains('myopia retinopathy') | original_dataframe['LD'].str.contains('myopia retinopathy') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 374    375           64        Male   375_left.jpg   375_right.jpg
# 650    651           58        Male   651_left.jpg   651_right.jpg
# 935    938           76        Male   938_left.jpg   938_right.jpg
# 1007  1020           67        Male  1020_left.jpg  1020_right.jpg
# 1038  1065           75        Male  1065_left.jpg  1065_right.jpg
# 1144  1213           76        Male  1213_left.jpg  1213_right.jpg
# 1154  1225           39        Male  1225_left.jpg  1225_right.jpg
# 1200  1279           84      Female  1279_left.jpg  1279_right.jpg
# 1209  1289           71      Female  1289_left.jpg  1289_right.jpg
#
#                                                      LD  \
# 374     punctate inner choroidopathy,myopia retinopathy
# 650   wet age-related macular degeneration,myopia re...
# 935   dry age-related macular degeneration,myopia re...
# 1007                   glaucoma,intraretinal hemorrhage
# 1038               dry age-related macular degeneration
# 1144                        glaucoma,myopia retinopathy
# 1154                        glaucoma,myopia retinopathy
# 1200                        glaucoma,myopia retinopathy
# 1209                        glaucoma,myopia retinopathy
#
#                                                      RD  N  D  G  C  A  H  M  \
# 374     punctate inner choroidopathy,myopia retinopathy  0  0  0  0  0  0  1
# 650                                  myopia retinopathy  0  0  0  0  1  0  1
# 935   diabetic retinopathy,dry age-related macular d...  0  1  0  0  1  0  1
# 1007                                 myopia retinopathy  0  0  1  0  0  0  1
# 1038                                 myopia retinopathy  0  0  0  0  1  0  1
# 1144                        glaucoma,myopia retinopathy  0  0  1  0  0  0  1
# 1154                        glaucoma,myopia retinopathy  0  0  1  0  0  0  1
# 1200                        glaucoma,myopia retinopathy  0  0  1  0  0  0  1
# 1209                        glaucoma,myopia retinopathy  0  0  1  0  0  0  1
#
#       O
# 374   1
# 650   0
# 935   0
# 1007  1
# 1038  0
# 1144  0
# 1154  0
# 1200  0
# 1209  0

# %%
original_dataframe[original_dataframe['RD'].str.contains('age-related macular degeneration') | original_dataframe['LD'].str.contains('age-related macular degeneration') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 43      43           35        Male    43_left.jpg    43_right.jpg
# 48      48           69      Female    48_left.jpg    48_right.jpg
# 53      53           65      Female    53_left.jpg    53_right.jpg
# 55      55           62        Male    55_left.jpg    55_right.jpg
# 71      71           56      Female    71_left.jpg    71_right.jpg
# 102    102           73      Female   102_left.jpg   102_right.jpg
# 126    126           66        Male   126_left.jpg   126_right.jpg
# 136    136           75      Female   136_left.jpg   136_right.jpg
# 152    152           55        Male   152_left.jpg   152_right.jpg
# 153    153           79        Male   153_left.jpg   153_right.jpg
# 158    158           61        Male   158_left.jpg   158_right.jpg
# 160    160           40      Female   160_left.jpg   160_right.jpg
# 162    162           76      Female   162_left.jpg   162_right.jpg
# 164    164           62      Female   164_left.jpg   164_right.jpg
# 168    168           66        Male   168_left.jpg   168_right.jpg
# 178    178           54        Male   178_left.jpg   178_right.jpg
# 209    210           70        Male   210_left.jpg   210_right.jpg
# 211    212           67      Female   212_left.jpg   212_right.jpg
# 212    213           44      Female   213_left.jpg   213_right.jpg
# 229    230           56      Female   230_left.jpg   230_right.jpg
# 234    235           67        Male   235_left.jpg   235_right.jpg
# 237    238           70        Male   238_left.jpg   238_right.jpg
# 242    243           67        Male   243_left.jpg   243_right.jpg
# 246    247           49        Male   247_left.jpg   247_right.jpg
# 259    260           63      Female   260_left.jpg   260_right.jpg
# 263    264           58        Male   264_left.jpg   264_right.jpg
# 264    265           81        Male   265_left.jpg   265_right.jpg
# 265    266           67        Male   266_left.jpg   266_right.jpg
# 269    270           64        Male   270_left.jpg   270_right.jpg
# 291    292           55        Male   292_left.jpg   292_right.jpg
# 310    311           65        Male   311_left.jpg   311_right.jpg
# 314    315           57      Female   315_left.jpg   315_right.jpg
# 318    319           58      Female   319_left.jpg   319_right.jpg
# 320    321           54      Female   321_left.jpg   321_right.jpg
# 333    334           74      Female   334_left.jpg   334_right.jpg
# 358    359           54        Male   359_left.jpg   359_right.jpg
# 1483  0
# 1484  0
# 1485  0
# 1486  0
# 1487  0
# 1488  0
# 1489  0
# 1490  0
# 1491  0
# 1492  0
# 1493  0
# 1497  0
# 1498  0
# 1499  0
# 1500  0
# 1501  0
# 1502  0
# 1503  0
# 1504  0
# 1505  0
# 1506  0
# 1507  0
# 1508  1
# 1509  0
# 1510  0
# 1511  0
# 1512  0
# 1513  1
# 1514  0
# 1515  0
# 1516  1
# 1517  1
# 1518  0
# 1545  1
# 1546  1
# 1549  1
# 1552  1
# 1556  1
# 2866  0
# 2943  0
# 3187  0
# 3499  0

# %% [markdown]
# Results:
# - age-related macular degeneration : ARMD (A)
# - myopia retinopathy : Myopia (M)

# %% [markdown]
# From the above tables we can see that myopia & age related.... should be in the pure myopia_set and pure_armd_set accordingly. Now the 'suspicious' diagnosis terms will be investigated.

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspected cataract') | original_dataframe['LD'].str.contains('suspected cataract') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1555  2074           24        Male  2074_left.jpg  2074_right.jpg
#
#                       LD                           RD  N  D  G  C  A  H  M  O
# 1555  glaucoma,lens dust  cataract,suspected cataract  0  0  1  1  0  0  0  0

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspected diabetic retinopathy') | original_dataframe['LD'].str.contains('suspected diabetic retinopathy') ]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 752  754           64        Male  754_left.jpg  754_right.jpg
#
#                                                     LD  \
# 752  hypertensive retinopathy,suspected diabetic re...
#
#                                                     RD  N  D  G  C  A  H  M  O
# 752  hypertensive retinopathy,suspected diabetic re...  0  1  0  0  0  1  0  0

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspected microvascular anomalies') | original_dataframe['LD'].str.contains('suspected microvascular anomalies') ]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus             LD  \
# 151  151           48        Male  151_left.jpg  151_right.jpg  normal fundus
#
#                                                     RD  N  D  G  C  A  H  M  O
# 151  white vessel,proliferative diabetic retinopath...  0  1  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspected macular epimacular membrane') | original_dataframe['LD'].str.contains('suspected macular epimacular membrane') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1379  1559           56      Female  1559_left.jpg  1559_right.jpg
#
#                        LD                                                 RD  \
# 1379  pathological myopia  pathological myopia,suspected macular epimacul...
#
#       N  D  G  C  A  H  M  O
# 1379  0  0  0  0  0  0  1  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspected moderate non proliferative retinopathy') | original_dataframe['LD'].str.contains('suspected moderate non proliferative retinopathy') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1363  1543           30      Female  1543_left.jpg  1543_right.jpg
#
#                                                      LD                   RD  \
# 1363  suspected moderate non proliferative retinopat...  pathological myopia
#
#       N  D  G  C  A  H  M  O
# 1363  0  1  0  0  0  0  1  0

# %%
original_dataframe[original_dataframe['RD'].str.contains('suspicious diabetic retinopathy') | original_dataframe['LD'].str.contains('suspicious diabetic retinopathy') ]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 744  746           59        Male  746_left.jpg  746_right.jpg
#
#                                                     LD  \
# 744  suspected glaucoma,suspicious diabetic retinop...
#
#                                                     RD  N  D  G  C  A  H  M  O
# 744  suspected glaucoma,suspicious diabetic retinop...  0  1  1  0  0  0  0  0

# %% [markdown]
# Reults:
# - 'suspected cataract': cataract
# - 'suspected diabetic retinopathy': diabetes
# - 'suspected macular epimacular membrane': others
# - 'suspected microvascular anomalies': others
# - 'suspected moderate non proliferative retinopathy': diabetes
# - 'suspicious diabetic retinopathy': diabetes

# %% [markdown]
# Other items will now be investigated. I hypothesize that most of them will be under Others.

# %%
original_dataframe[original_dataframe['RD'].str.contains('vitreous opacity')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1246  1373           68        Male  1373_left.jpg  1373_right.jpg
#
#                             LD  \
# 1246  hypertensive retinopathy
#
#                                                      RD  N  D  G  C  A  H  M  \
# 1246  hypertensive retinopathy,branch retinal vein o...  0  0  0  0  0  1  0
#
#       O
# 1246  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('central serous chorioretinopathy') | original_dataframe['LD'].str.contains('central serous chorioretinopathy') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1549  2053           47        Male  2053_left.jpg  2053_right.jpg
#
#                                         LD                                RD  \
# 1549  dry age-related macular degeneration  central serous chorioretinopathy
#
#       N  D  G  C  A  H  M  O
# 1549  0  0  0  0  1  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('choroidal nevus') | original_dataframe['LD'].str.contains('choroidal nevus') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1135  1202           42      Female  1202_left.jpg  1202_right.jpg
#
#                                                      LD  \
# 1135  dry age-related macular degeneration,choroidal...
#
#                                         RD  N  D  G  C  A  H  M  O
# 1135  dry age-related macular degeneration  0  0  0  0  1  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('diffuse chorioretinal atrophy') | original_dataframe['LD'].str.contains('diffuse chorioretinal atrophy') ]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 845  847           56      Female  847_left.jpg  847_right.jpg
#
#                                                     LD  \
# 845  wet age-related macular degeneration,diffuse c...
#
#                                                     RD  N  D  G  C  A  H  M  O
# 845  dry age-related macular degeneration,post lase...  0  0  0  0  1  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('diffuse retinal atrophy') | original_dataframe['LD'].str.contains('diffuse retinal atrophy') ]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1179  1255           33        Male  1255_left.jpg  1255_right.jpg
#
#                                     LD        RD  N  D  G  C  A  H  M  O
# 1179  glaucoma,diffuse retinal atrophy  glaucoma  0  0  1  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('fundus laser photocoagulation spots') | original_dataframe['LD'].str.contains('fundus laser photocoagulation spots')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1196  1273           62        Male  1273_left.jpg  1273_right.jpg
#
#                                        LD  \
# 1196  fundus laser photocoagulation spots
#
#                                                 RD  N  D  G  C  A  H  M  O
# 1196  glaucoma,fundus laser photocoagulation spots  0  0  1  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('glial remnants anterior to the optic disc') | original_dataframe['LD'].str.contains('glial remnants anterior to the optic disc')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 755  757           58      Female  757_left.jpg  757_right.jpg
#
#                                          LD  \
# 755  moderate non proliferative retinopathy
#
#                                             RD  N  D  G  C  A  H  M  O
# 755  glial remnants anterior to the optic disc  0  1  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('image offset') | original_dataframe['LD'].str.contains('image offset')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1170  1243           81      Female  1243_left.jpg  1243_right.jpg
#
#                 LD                                             RD  N  D  G  C  \
# 1170  image offset  dry age-related macular degeneration,glaucoma  0  0  1  0
#
#       A  H  M  O
# 1170  1  0  0  0

# %%
original_dataframe[original_dataframe['RD'].str.contains('intraretinal hemorrhage') | original_dataframe['LD'].str.contains('intraretinal hemorrhage')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1007  1020           67        Male  1020_left.jpg  1020_right.jpg
# 1199  1277           74        Male  1277_left.jpg  1277_right.jpg
#
#                                     LD                  RD  N  D  G  C  A  H  \
# 1007  glaucoma,intraretinal hemorrhage  myopia retinopathy  0  0  1  0  0  0
# 1199  glaucoma,intraretinal hemorrhage            glaucoma  0  0  1  0  0  0
#
#       M  O
# 1007  1  1
# 1199  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('intraretinal microvascular abnormality') | original_dataframe['LD'].str.contains('intraretinal microvascular abnormality')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 3381  4551           53        Male  4551_left.jpg  4551_right.jpg
# 3480  4659           42        Male  4659_left.jpg  4659_right.jpg
#
#                                      LD  \
# 3381  mild nonproliferative retinopathy
# 3480  mild nonproliferative retinopathy
#
#                                           RD  N  D  G  C  A  H  M  O
# 3381  intraretinal microvascular abnormality  0  1  0  0  0  0  0  1
# 3480  intraretinal microvascular abnormality  0  1  0  0  0  0  0  1

# %% [markdown]
# Results:
# - 'central serous chorioretinopathy' : Others
# - 'choroidal nevus': Others
# - 'diffuse chorioretinal atrophy': Others
# - 'diffuse retinal atrophy': Others
# - 'fundus laser photocoagulation spots': Others
# - 'glial remnants anterior to the optic disc': Others
# - *'image offset': Normal
# - 'intraretinal hemorrhage': Others
# - 'intraretinal microvascular abnormality': Others
# - 'vitreous opacity' : Others
#
# *This is determined by inference. The only situations in which normal is not highlighted is if there's a disease, so given O was not positive and the other two labels are spoken for, I would estimate normal to be the most likely

# %%
original_dataframe[original_dataframe['RD'].str.contains('macular pigmentation disorder') | original_dataframe['LD'].str.contains('macular pigmentation disorder')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1293  1442           63        Male  1442_left.jpg  1442_right.jpg
#
#                                                      LD  \
# 1293  glaucoma,mild nonproliferative retinopathy,mac...
#
#                          RD  N  D  G  C  A  H  M  O
# 1293  pigmentation disorder  0  1  1  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('old central retinal vein occlusion') | original_dataframe['LD'].str.contains('old central retinal vein occlusion')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1152  1221           70        Male  1221_left.jpg  1221_right.jpg
# 1186  1263           62        Male  1263_left.jpg  1263_right.jpg
# 1547  2048           63        Male  2048_left.jpg  2048_right.jpg
#
#                                         LD  \
# 1152  glaucoma,macular epiretinal membrane
# 1186    old central retinal vein occlusion
# 1547              hypertensive retinopathy
#
#                                                RD  N  D  G  C  A  H  M  O
# 1152  glaucoma,old central retinal vein occlusion  0  0  1  0  0  0  0  1
# 1186            glaucoma,hypertensive retinopathy  0  0  1  0  0  1  0  1
# 1547  glaucoma,old central retinal vein occlusion  0  0  1  0  0  1  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('old choroiditis') | original_dataframe['LD'].str.contains('old choroiditis')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 377  378           54        Male  378_left.jpg  378_right.jpg
#
#                                               LD  \
# 377  old choroiditis,macular epiretinal membrane
#
#                                          RD  N  D  G  C  A  H  M  O
# 377  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('optic disk epiretinal membrane') | original_dataframe['LD'].str.contains('optic disk epiretinal membrane')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 450  451           56        Male  451_left.jpg  451_right.jpg
#
#                                  LD                                      RD  \
# 450  optic disk epiretinal membrane  moderate non proliferative retinopathy
#
#      N  D  G  C  A  H  M  O
# 450  0  1  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('peripapillary atrophy') | original_dataframe['LD'].str.contains('peripapillary atrophy')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1387  1567           47        Male  1567_left.jpg  1567_right.jpg
# 1391  1571           65        Male  1571_left.jpg  1571_right.jpg
# 1393  1573           69      Female  1573_left.jpg  1573_right.jpg
# 1394  1574           73      Female  1574_left.jpg  1574_right.jpg
# 1407  1591           62      Female  1591_left.jpg  1591_right.jpg
# 1410  1595            1      Female  1595_left.jpg  1595_right.jpg
# 1411  1597           64      Female  1597_left.jpg  1597_right.jpg
# 1412  1598           60      Female  1598_left.jpg  1598_right.jpg
# 1426  1614           56      Female  1614_left.jpg  1614_right.jpg
# 1436  1626           74        Male  1626_left.jpg  1626_right.jpg
# 1437  1628           56        Male  1628_left.jpg  1628_right.jpg
# 1441  1640           45        Male  1640_left.jpg  1640_right.jpg
# 1442  1642           63        Male  1642_left.jpg  1642_right.jpg
# 1443  1643           69        Male  1643_left.jpg  1643_right.jpg
# 1458  1683           72      Female  1683_left.jpg  1683_right.jpg
# 1463  1716           66        Male  1716_left.jpg  1716_right.jpg
#
#                                             LD  \
# 1387  tessellated fundus,peripapillary atrophy
# 1391                       pathological myopia
# 1393  tessellated fundus,peripapillary atrophy
# 1394  tessellated fundus,peripapillary atrophy
# 1407                       pathological myopia
# 1410  tessellated fundus,peripapillary atrophy
# 1411  tessellated fundus,peripapillary atrophy
# 1412                       pathological myopia
# 1426  tessellated fundus,peripapillary atrophy
# 1436                       pathological myopia
# 1437                       pathological myopia
# 1441                       pathological myopia
# 1442  tessellated fundus,peripapillary atrophy
# 1443                       pathological myopia
# 1458                     peripapillary atrophy
# 1463                       pathological myopia
#
#                                             RD  N  D  G  C  A  H  M  O
# 1387                       pathological myopia  0  0  0  0  0  0  1  1
# 1391  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1393                       pathological myopia  0  0  0  0  0  0  1  1
# 1394                       pathological myopia  0  0  0  0  0  0  1  1
# 1407  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1410                       pathological myopia  0  0  0  0  0  0  1  1
# 1411                       pathological myopia  0  0  0  0  0  0  1  1
# 1412  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1426                       pathological myopia  0  0  0  0  0  0  1  1
# 1436  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1437  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1441  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1442                       pathological myopia  0  0  0  0  0  0  1  1
# 1443  tessellated fundus,peripapillary atrophy  0  0  0  0  0  0  1  1
# 1458                       pathological myopia  0  0  0  0  0  0  1  1
# 1463                     peripapillary atrophy  0  0  0  0  0  0  1  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('punctate inner choroidopathy') | original_dataframe['LD'].str.contains('punctate inner choroidopathy')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 374  375           64        Male  375_left.jpg  375_right.jpg
#
#                                                   LD  \
# 374  punctate inner choroidopathy,myopia retinopathy
#
#                                                   RD  N  D  G  C  A  H  M  O
# 374  punctate inner choroidopathy,myopia retinopathy  0  0  0  0  0  0  1  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('retinal detachment') | original_dataframe['LD'].str.contains('retinal detachment')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 20      20           64      Female    20_left.jpg    20_right.jpg
# 408    409           55        Male   409_left.jpg   409_right.jpg
# 1440  1638           59        Male  1638_left.jpg  1638_right.jpg
#
#                                                LD  \
# 20              rhegmatogenous retinal detachment
# 408   lens dust,rhegmatogenous retinal detachment
# 1440                          pathological myopia
#
#                                          RD  N  D  G  C  A  H  M  O
# 20                  lens dust,normal fundus  0  0  0  0  0  0  0  1
# 408                 lens dust,normal fundus  0  0  0  0  0  0  0  1
# 1440  retinal detachment,tessellated fundus  0  0  0  0  0  0  1  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('retinal pigment epithelial hypertrophy') | original_dataframe['LD'].str.contains('retinal pigment epithelial hypertrophy')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 599  600           50        Male  600_left.jpg  600_right.jpg
# 699  701           60        Male  701_left.jpg  701_right.jpg
#
#                                     LD  \
# 599  mild nonproliferative retinopathy
# 699                      normal fundus
#
#                                                     RD  N  D  G  C  A  H  M  O
# 599  retinal pigment epithelial hypertrophy,moderat...  0  1  0  0  0  0  0  1
# 699  moderate non proliferative retinopathy,retinal...  0  1  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('retinal pigment epithelium atrophy') | original_dataframe['LD'].str.contains('retinal pigment epithelium atrophy')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 108  108           54      Female  108_left.jpg  108_right.jpg
#
#                                                     LD             RD  N  D  \
# 108  retinal pigment epithelium atrophy,diabetic re...  normal fundus  0  1
#
#      G  C  A  H  M  O
# 108  0  0  0  0  0  1

# %%
original_dataframe[original_dataframe['RD'].str.contains('vascular loops') | original_dataframe['LD'].str.contains('vascular loops')]
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 791  793           66      Female  793_left.jpg  793_right.jpg
#
#                                                    LD  \
# 791  lens dust,moderate non proliferative retinopathy
#
#                            RD  N  D  G  C  A  H  M  O
# 791  lens dust,vascular loops  0  1  0  0  0  0  0  1

# %% [markdown]
# Results:
# - 'macular pigmentation disorder': Others
# - 'old central retinal vein occlusion': Others
# - 'old choroiditis': Others
# - 'optic disk epiretinal membrane': Others
# - 'peripapillary atrophy': Others
# - 'punctate inner choroidopathy': Others
# - 'retinal detachment': Others
# - 'retinal pigment epithelial hypertrophy': Others
# - 'retinal pigment epithelium atrophy': Others
# - 'vascular loops': Others

# %% [markdown]
# Most of the items from the remaining_set are for the Others category so the label sets will be adjusted accordingly

# %%
remaining_others_list = ['suspected macular epimacular membrane','suspected microvascular anomalies','central serous chorioretinopathy' 
,'diffuse chorioretinal atrophy','choroidal nevus','diffuse retinal atrophy','fundus laser photocoagulation spots' 
,'glial remnants anterior to the optic disc', 'intraretinal hemorrhage', 'intraretinal microvascular abnormality'
,'macular pigmentation disorder','old central retinal vein occlusion','old choroiditis','optic disk epiretinal membrane'
,'peripapillary atrophy','punctate inner choroidopathy','retinal detachment','retinal pigment epithelial hypertrophy'
,'retinal pigment epithelium atrophy','vascular loops','vitreous opacity']

# %%
len(remaining_others_list)
# Out:
# 21

# %%
pure_armd_set.add('age-related macular degeneration')
pure_myopia_set.add('myopia retinopathy')
pure_diabetes_set.update(['suspected diabetic retinopathy', 'suspected moderate non proliferative retinopathy', 'suspicious diabetic retinopathy'])
pure_cataract_set.add('suspected cataract')
pure_others_set.update(remaining_others_list)
pure_normal_fundus_set.add('image offset')

# %%
total_pure_set = (pure_normal_fundus_set | pure_myopia_set | pure_glaucoma_set | pure_armd_set | pure_diabetes_set |
                         pure_hypertension_set | pure_cataract_set | pure_others_set)

# %%
len(total_pure_set)
# Out:
# 103

# %%
original_diagnosis_set - total_pure_set
# Out:
# set()

# %% [markdown]
# ## Fixing Data so it's a single image to a row.
# The idea will be to isolate the relevant left image columns and relevant right image columns + data.

# %%
pd.set_option('display.max_rows', 10)
original_dataframe
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        3           66        Male     3_left.jpg     3_right.jpg
# 4        4           53        Male     4_left.jpg     4_right.jpg
# ...    ...          ...         ...            ...             ...
# 3495  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3496  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3497  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3498  4690           57        Male  4690_left.jpg  4690_right.jpg
# 3499  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                                      LD  \
# 0                                              cataract
# 1                                         normal fundus
# 2     laser spot,moderate non proliferative retinopathy
# 3                                         normal fundus
# 4                           macular epiretinal membrane
# ...                                                 ...
# 3495                severe nonproliferative retinopathy
# 3496             moderate non proliferative retinopathy
# 3497                  mild nonproliferative retinopathy
# 3498                  mild nonproliferative retinopathy
# 3499  hypertensive retinopathy,age-related macular d...
#
#                                                      RD  N  D  G  C  A  H  M  \
# 0                                         normal fundus  0  0  0  1  0  0  0
# 1                                         normal fundus  1  0  0  0  0  0  0
# 2                moderate non proliferative retinopathy  0  1  0  0  0  0  0
# 3                       branch retinal artery occlusion  0  0  0  0  0  0  0
# 4                     mild nonproliferative retinopathy  0  1  0  0  0  0  0
# ...                                                 ... .. .. .. .. .. .. ..
# 3495                 proliferative diabetic retinopathy  0  1  0  0  0  0  0
# 3496             moderate non proliferative retinopathy  0  1  0  0  0  0  0
# 3497                                      normal fundus  0  1  0  0  0  0  0
# 3498                  mild nonproliferative retinopathy  0  1  0  0  0  0  0
# 3499  hypertensive retinopathy,age-related macular d...  0  0  0  0  1  1  0
#
#       O
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# ...  ..
# 3495  0
# 3496  0
# 3497  0
# 3498  0
# 3499  0
#
# [3500 rows x 15 columns]

# %%
original_dataframe.columns
# Out:
# Index(['ID', 'Patient Age', 'Patient Sex', 'Left-Fundus', 'Right-Fundus', 'LD',
#        'RD', 'N', 'D', 'G', 'C', 'A', 'H', 'M', 'O'],
#       dtype='object')

# %% [markdown]
# Left Columns are: [ID, Patient Age, Patient Sex, Left-Fundus, LD, N, D, G, C, A, H, M, O]
# Right Columns are: [ID, Patient Age, Patient Sex, Right-Fundus, RD, N, D, G, C, A, H, M, O]
#
# Rename the following:
# - ID column to Patient ID
# - LD/RD to Diagnosis
# - Left Fundus/Right Fundus to Filename

# %%
left_fundus_images = original_dataframe.filter(['ID', 'Patient Age', 'Patient Sex', 'Left-Fundus', 'LD', 'N', 'D', 'G', 'C', 'A','H', 'M', 'O'])
right_fundus_images = original_dataframe.filter(['ID', 'Patient Age', 'Patient Sex', 'Right-Fundus', 'RD', 'N', 'D', 'G', 'C', 'A','H', 'M', 'O'])

# %%
left_fundus_images.rename(columns = {'LD':'Diagnosis', 'ID': 'Patient ID', 'Left-Fundus': 'Filename'}, inplace = True)
right_fundus_images.rename(columns = {'RD':'Diagnosis', 'ID': 'Patient ID', 'Right-Fundus': 'Filename'}, inplace = True)

# %%
left_fundus_images.loc[:, ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']] = 0
right_fundus_images.loc[:, ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']] = 0

# %%
left_fundus_images['Diagnosis'] = left_fundus_images['Diagnosis'].apply(lambda x: x.split(','))
right_fundus_images['Diagnosis'] = right_fundus_images['Diagnosis'].apply(lambda x: x.split(','))

# %%
def filter_values_in_set(dataframe, unique_set, column):
    filter_condition = dataframe['Diagnosis'].apply(lambda x: any(item in unique_set for item in x))
    dataframe.loc[filter_condition, column] = 1

# %%
filter_values_in_set(left_fundus_images, pure_normal_fundus_set, 'N')
filter_values_in_set(left_fundus_images, pure_diabetes_set, 'D')
filter_values_in_set(left_fundus_images, pure_glaucoma_set, 'G')
filter_values_in_set(left_fundus_images, pure_cataract_set, 'C')
filter_values_in_set(left_fundus_images, pure_armd_set, 'A')
filter_values_in_set(left_fundus_images, pure_hypertension_set, 'H')
filter_values_in_set(left_fundus_images, pure_myopia_set, 'M')
filter_values_in_set(left_fundus_images, pure_others_set, 'O')

# %%
filter_values_in_set(right_fundus_images, pure_normal_fundus_set, 'N')
filter_values_in_set(right_fundus_images, pure_diabetes_set, 'D')
filter_values_in_set(right_fundus_images, pure_glaucoma_set, 'G')
filter_values_in_set(right_fundus_images, pure_cataract_set, 'C')
filter_values_in_set(right_fundus_images, pure_armd_set, 'A')
filter_values_in_set(right_fundus_images, pure_hypertension_set, 'H')
filter_values_in_set(right_fundus_images, pure_myopia_set, 'M')
filter_values_in_set(right_fundus_images, pure_others_set, 'O')

# %%
right_fundus_images

# %%
left_fundus_images

# %%
new_dataframe = pd.concat([left_fundus_images, right_fundus_images], ignore_index = True)

# %%
new_dataframe

# %%
new_dataframe.to_excel('Processed_data.xlsx', index=False)

# %%
df = pd.read_excel('Processed_data.xlsx')

# %%
df.head()
# Out:
#    Patient ID  Patient Age Patient Sex    Filename  \
# 0           0           69      Female  0_left.jpg
# 1           1           57        Male  1_left.jpg
# 2           2           42        Male  2_left.jpg
# 3           3           66        Male  3_left.jpg
# 4           4           53        Male  4_left.jpg
#
#                                            Diagnosis  N  D  G  C  A  H  M  O
# 0                                       ['cataract']  0  0  0  1  0  0  0  0
# 1                                  ['normal fundus']  1  0  0  0  0  0  0  0
# 2  ['laser spot', 'moderate non proliferative ret...  0  1  0  0  0  0  0  1
# 3                                  ['normal fundus']  1  0  0  0  0  0  0  0
# 4                    ['macular epiretinal membrane']  0  0  0  0  0  0  0  1

# %% [markdown]
# ### Correlation

# %%
'image offset': Normal

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
### Choose columns

# %%
choice_columns = original_dataframe.drop(['ID','N', 'D', 'G','C', 'A', 'H', 'M', 'O','Left-Fundus','Right-Fundus'], axis=1)

# %%
choice_columns

# %%
label_encoder = LabelEncoder()

# Apply Label Encoding to specific columns
choice_columns['Patient Sex'] = label_encoder.fit_transform(choice_columns['Patient Sex']) 
#choice_columns['Left-Diagnostic Keywords'] = label_encoder.fit_transform(choice_columns['Left-Diagnostic Keywords'])
#['Right-Diagnostic Keywords'] = label_encoder.fit_transform(choice_columns['Right-Diagnostic Keywords'])
choice_columns['LD'] = label_encoder.fit_transform(choice_columns['LD'])
choice_columns['RD'] = label_encoder.fit_transform(choice_columns['RD'])

# %%
corr_matrix = choice_columns.corr()
# Visualize the correlation matrix as a heatmap
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ### Some eye diseases compared to a normal eye

# %% [markdown]
# <table>
#    <tr style="text-align: center;">
#     <th>Cataract</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/0_left.jpg" alt="Cataract" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
# <table>
#    <tr style="text-align: center;">
#     <th>pathological myopia</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/13_left.jpg" alt="pathological myopia" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
#
# <table>
#    <tr style="text-align: center;">
#     <th>retinal pigmentation</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/12_left.jpg" alt="retinal pigmentation" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
# <table>
#    <tr style="text-align: center;">
#     <th>rhegmatogenous retinal detachment</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/20_left.jpg" alt="retinal pigmentation" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
# <table>
#    <tr style="text-align: center;">
#     <th>epiretinal membrane</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/29_left.jpg" alt="epiretinal membrane" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
#
#
# <table>
#    <tr style="text-align: center;">
#     <th>macular hole</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/38_left.jpg" alt="macular hole" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>
#
# <table>
#    <tr style="text-align: center;">
#     <th>chorioretinal atrophy</th>
#     <th>Normal</th>
#   </tr>
#   <tr>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/78_left.jpg" alt="chorioretinal atrophy" width="300" height="300"></td>
#     <td><img src="./ocular-disease-recognition-odir5k/ODIR-5k/ODIR-5k/Training Images/1_left.jpg" alt="Normal" width="300" height="300"></td>
#   </tr>
# </table>

# %%
df.head()
# Out:
#    Patient ID  Patient Age Patient Sex    Filename  \
# 0           0           69      Female  0_left.jpg
# 1           1           57        Male  1_left.jpg
# 2           2           42        Male  2_left.jpg
# 3           3           66        Male  3_left.jpg
# 4           4           53        Male  4_left.jpg
#
#                                            Diagnosis  N  D  G  C  A  H  M  O
# 0                                       ['cataract']  0  0  0  1  0  0  0  0
# 1                                  ['normal fundus']  1  0  0  0  0  0  0  0
# 2  ['laser spot', 'moderate non proliferative ret...  0  1  0  0  0  0  0  1
# 3                                  ['normal fundus']  1  0  0  0  0  0  0  0
# 4                    ['macular epiretinal membrane']  0  0  0  0  0  0  0  1

# %%
diagnosis_set = [pure_normal_fundus_set, pure_myopia_set, pure_glaucoma_set, pure_armd_set ,pure_diabetes_set,
                         pure_hypertension_set, pure_cataract_set, pure_others_set]

# %%
diagnosis_set = [pure_normal_fundus_set, pure_myopia_set, pure_glaucoma_set, 
                 pure_armd_set ,pure_diabetes_set, pure_cataract_set]

diagnosis_name = ["Normal Fundus", "Myopia", "Glaucoma", "Age related Macular Degeneration", "Diabetes", "Cataract"]
fig, axes = plt.subplots(3, 2, figsize=(15, 25), sharey=False)

for dia_set in diagnosis_set:
    diz_count = [df["Diagnosis"].str.contains(dis).sum() for dis in dia_set]
    x = list(dia_set)
    y = diz_count
    
    i = diagnosis_set.index(dia_set)
    row, col = divmod(i, 2)
    ax = axes[row, col]
    ax.bar(x, y, width = 0.3)
    ax.set_title(diagnosis_name[i], fontsize=18)
    ax.set_ylabel('Count', fontsize=14)
    ax.tick_params(axis='x', labelrotation = 85)

plt.tight_layout()
# plt.show()
